# %% [markdown]
# # Imports

# %%
# !pip install sklearn
import pandas as pd
import numpy as np
from sklearn import linear_model as ln

# %% [markdown]
# # Loading data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df_raw = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Projetos-IA/house-rocket/kc_house_data.csv')

# %%
df_raw.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view  ...  grade  sqft_above  sqft_basement  \
# 0      5650     1.0           0     0  ...      7        1180              0
# 1      7242     2.0           0     0  ...      7        2170            400
# 2     10000     1.0           0     0  ...      6         770              0
# 3      5000     1.0           0     0  ...      7        1050            910
# 4      8080     1.0           0     0  ...      8        1680              0
#
#    yr_built  yr_renovated  zipcode      lat     long  sqft_living15  \
# 0      1955             0    98178  47.5112 -122.257           1340
# 1      1951          1991    98125  47.7210 -122.319           1690
# 2      1933             0    98028  47.7379 -122.233           2720
# 3      1965             0    98136  47.5208 -122.393           1360
# 4      1987             0    98074  47.6168 -122.045           1800
#
#    sqft_lot15
# 0        5650
# 1        7639
# 2        8062
# 3        5000
# 4        7503
#
# [5 rows x 21 columns]

# %% [markdown]
# # Data Preparation

# %%
# fatures
x_train = df_raw.drop(['price', 'date'], axis = 1)

#response variable
y_train = df_raw['price'].copy()

# %%
y_train.head()
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64

# %% [markdown]
# # Model Training

# %%
#model description
model_lr = ln.LinearRegression()

# model training
model_lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
#prediction
pred = model_lr.predict(x_train)

# %%
pred[0:100]
# Out:
# array([ 205766.26460962,  731219.64982987,  379097.88265418,
#         457424.13432523,  444789.05471813, 1451676.80046248,
#         277965.14285807,  135261.77208378,  329843.816244  ,
#         250731.25050364,  870212.88141892,  437789.72121283,
#         600311.43498102,  316903.13655571,  611557.85739088,
#         944453.29692627,  456573.68626297,  539004.69481032,
#         335024.25629838,  210585.07434924,  466088.95603625,
#        1116489.11078682,  330386.45026626,  130784.11743749,
#         545423.99906288,  310538.2602699 ,  802018.137649  ,
#         651875.20382832,  457699.20615298,  650018.45024574,
#         541202.9217009 ,  332196.71884796,  655096.04733209,
#         555240.33756533,  319817.17474398,  804301.35470887,
#         201145.17195314,  861533.54324502,  103130.75983525,
#         585745.32147531,  664511.5030735 ,  742662.60624431,
#         863042.39845941,  508391.02023423,  153710.08047341,
#         811721.66516489,   32096.77784439,  762323.19584884,
#         417855.61065256, 1530097.6252822 ,  185578.71195406,
#         658157.92714002,  471090.25997114,  498290.25253101,
#         789802.28617632,  773293.96241427,  271727.39865374,
#         467150.37020335, 1056923.77322495,  443395.18842529,
#         694554.24465644,  237766.54435053,  598068.6985004 ,
#         408857.34579782,  376054.00863779,  744927.55137086,
#         879888.08105547,  321711.45186217,  121851.74702502,
#         783019.32595654, 1399362.5056917 ,  460538.49633772,
#         800124.29246177,  390335.05311709,  300689.96053684,
#         991726.69237255,  413248.79001207,  310476.89799588,
#         413980.07473525,  802185.44256449,  412926.15633989,
#         218377.00510938,  449654.54032674,  434848.802698  ,
#         261756.27101988,  819846.02518008,  407338.5140397 ,
#         708935.71931333,  424310.54489837,  177895.94502964,
#         297041.36776153,  958741.14250685,  190018.37500694,
#         603396.37010423,  603396.37010423,  795519.96750257,
#         354071.72245305,  155387.93358101,  244625.66437785,
#         645182.95882837])

# %% [markdown]
# # Performance Metrics

# %%
df1 = df_raw.copy()

# %%
df1['prediction'] = pred

# %%
df1['error'] = df1['price'] - df1['prediction']
df1['error_abs'] = np.abs(df1['error'])

df1['error_perc'] = ((df1['price'] - df1['prediction']) / df1['price'])*100
df1['error_perc_abs'] = np.abs(df1['error_perc'])

# %%
df1[['id', 'price', 'prediction',  'error',  'error_abs', 'error_perc', 'error_perc_abs']].head()
# Out:
#            id     price     prediction          error      error_abs  \
# 0  7129300520  221900.0  205766.264610   16133.735390   16133.735390
# 1  6414100192  538000.0  731219.649830 -193219.649830  193219.649830
# 2  5631500400  180000.0  379097.882654 -199097.882654  199097.882654
# 3  2487200875  604000.0  457424.134325  146575.865675  146575.865675
# 4  1954400510  510000.0  444789.054718   65210.945282   65210.945282
#
#    error_perc  error_perc_abs
# 0    7.270723        7.270723
# 1  -35.914433       35.914433
# 2 -110.609935      110.609935
# 3   24.267527       24.267527
# 4   12.786460       12.786460

# %%
# mean absolute error
mae = np.mean(df1['error_abs'])
print('MAE: {}'.format(mae))
# Out:
# MAE: 125921.54419398653

# %%
#mean absolute percentage error
mape = np.mean(df1['error_perc_abs'])
print('MAPE: {}'.format(mape))
# Out:
# MAPE: 25.58051253618718
